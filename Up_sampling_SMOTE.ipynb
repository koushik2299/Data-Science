# %% [markdown]
# <a href="https://colab.research.google.com/github/koushik2299/Data-Science/blob/main/Up_sampling_SMOTE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# # Creating Classification Data

# %%
X,y = make_classification(n_samples=1000, n_redundant=0,n_features=2,weights=[0.9],random_state=142,n_clusters_per_class=1)

# %%
df1=pd.DataFrame(X,columns=["A","B"])
df2=pd.DataFrame(y,columns=["Features"])
df_final=pd.concat([df1,df2],axis=1)

# %%
df_final.head()
# Out:
#           A         B  Features
# 0 -0.575425  0.712021         0
# 1 -1.443354 -3.706778         0
# 2 -1.242656 -3.106729         0
# 3 -0.491842 -0.518748         0
# 4 -1.376329 -3.490758         0

# %%
df_final["Features"].value_counts()
# Out:
# 0    895
# 1    105
# Name: Features, dtype: int64

# %% [markdown]
# As we can see the dataframe is imbalanced so lets see the viz and make the changes accordingly

# %%
plt.scatter(df_final["A"],df_final["B"],c=df_final["Features"])
plt.show()

# %% [markdown]
# # **SMOTE ( Synthetic Minority Oversampling Technique)**
#
# ![smote.png](data:image/png;base64,...)

# %%
# !pip install imblearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
X,y = oversample.fit_resample(df_final[["A","B"]],df_final["Features"])

# %%
df1=pd.DataFrame(X,columns=["A","B"])
df2=pd.DataFrame(y,columns=["Features"])
df_final_mod=pd.concat([df1,df2],axis=1)

# %%
df_final.shape
# Out:
# (1000, 3)

# %%
df_final_mod.shape
# Out:
# (1790, 3)

# %%
plt.scatter(df_final_mod["A"],df_final_mod["B"],c=df_final_mod["Features"])
plt.show()
